# %% [markdown]
# # Capstone Project
# ## Probabilistic generative models
# ### Instructions
#
# In this notebook, you will practice working with generative models, using both normalising flow networks and the variational autoencoder algorithm. You will create a synthetic dataset with a normalising flow with randomised parameters. This dataset will then be used to train a variational autoencoder, and you will used the trained model to interpolate between the generated images. You will use concepts from throughout this course, including Distribution objects, probabilistic layers, bijectors, ELBO optimisation and KL divergence regularisers.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (File -> Download as -> PDF via LaTeX). You should then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports below. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors
tfpl = tfp.layers

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# For the capstone project, you will create your own image dataset from contour plots of a transformed distribution using a random normalising flow network. You will then use the variational autoencoder algorithm to train generative and inference networks, and synthesise new images by interpolating in the latent space.

# %% [markdown]
# #### The normalising flow
# * To construct the image dataset, you will build a normalising flow to transform the 2-D Gaussian random variable $z=(z_1, z_2)$, which has mean $\mathbf{0}$ and covariance matrix $\Sigma=\sigma^2\mathbf{I}_2$, with $\sigma=0.3$.
# * This normalising flow uses bijectors that are parameterised by the following random variables:
#   * $\theta \sim U[0, 2\pi)$
#   * $a \sim N(3, 1)$
#
# The complete normalising flow is given by the following chain of transformations:
# * $f_1(z) = (z_1, z_2 - 2)$,
# * $f_2(z) = (z_1, \frac{z_2}{2})$,
# * $f_3(z) = (z_1, z_2 + az_1^2)$,
# * $f_4(z) = Rz$, where $R$ is a rotation matrix with angle $\theta$,
# * $f_5(z) = \tanh(z)$, where the $\tanh$ function is applied elementwise.
#
# The transformed random variable $x$ is given by $x = f_5(f_4(f_3(f_2(f_1(z)))))$.
# * You should use or construct bijectors for each of the transformations $f_i$, $i=1,\ldots, 5$, and use `tfb.Chain` and `tfb.TransformedDistribution` to construct the final transformed distribution.
# * Ensure to implement the `log_det_jacobian` methods for any subclassed bijectors that you write.
# * Display a scatter plot of samples from the base distribution.
# * Display 4 scatter plot images of the transformed distribution from your random normalising flow, using samples of $\theta$ and $a$. Fix the axes of these 4 plots to the range $[-1, 1]$.

# %% [markdown]
# # Define important stuff

# %%
def getBaseDist(dims = 2, theta = 0.3):
  mean = [0] * dims
  stdDev = [theta] * dims
  return tfd.MultivariateNormalDiag(loc=mean, scale_diag=stdDev)

# %%
from math import pi

def getRandomVariables():
  theta = tfd.Uniform(0, pi)
  a = tfd.Normal(3, 1)
  return theta,a

# %%
# custom Bijector for function 3
class AddMultQuared(tfb.Bijector):
  def __init__(self,a,valArgs = False,forwardMinEventNdims = 1,name ="F3"):
    super(AddMultQuared,self).__init__(
        validate_args = valArgs,
        name = name,
        forward_min_event_ndims = forwardMinEventNdims
        ) 
    self.a = a

  def _forward(self,x):
    x = tf.cast(x, tf.float32)
    t = tf.zeros(x.shape[:-1]+[1], dtype=x.dtype)
    return x + tf.concat([t, self.a * x[..., 0, tf.newaxis]**2], axis=-1)


  def _inverse(self,y):
    y = tf.cast(y, tf.float32)
    t = tf.zeros(y.shape[:-1]+[1], dtype=y.dtype)
    return y - tf.concat([t, self.a * y[..., 0, tf.newaxis]**2], axis=-1)

  def _forward_log_det_jacobian(self, x):
    op =  1 - 2 * self.a * x[..., 1]
    return tf.math.log(tf.math.abs(op))

# %%
class RotateBijector(tfb.Bijector):
  def __init__(self,theta,valArgs = False,forwardMinEventNdims = 1,name ="F4"):
    super(RotateBijector,self).__init__(
        validate_args = valArgs,
        name = name,
        forward_min_event_ndims = forwardMinEventNdims
        ) 
    self.matTransform = tf.convert_to_tensor(
        [
         [tf.math.cos(theta),-tf.math.sin(theta)],
         [tf.math.sin(theta),tf.math.cos(theta)]
        ]
        ,tf.float32
    )

  def _forward(self,x):
    return tf.linalg.matvec(self.matTransform, x)


  def _inverse(self,y):
    return tf.linalg.matvec(tf.transpose(self.matTransform), y)

  def _forward_log_det_jacobian(self, x):
    return tf.constant(0, dtype=x.dtype)

# %%
def performTransformation(baseDistribution,a,theta):
  f1 = tfb.Shift([0,-1])
  f2 = tfb.Scale([1,0.5])
  f3 = AddMultQuared(a)
  f4 = RotateBijector(theta)
  f5 = tfb.Tanh()
  normalizationFlow = tfb.Chain([f5,f4,f3,f2,f1])
  return normalizationFlow, tfd.TransformedDistribution(baseDistribution, normalizationFlow)

# %% [markdown]
# # Instanciate Base Distribution

# %%
baseDistribution = getBaseDist()
baseDistribution
# Out:
# <tfp.distributions.MultivariateNormalDiag 'MultivariateNormalDiag' batch_shape=[] event_shape=[2] dtype=float32>

# %%
nSamples = 1000
samples = baseDistribution.sample(nSamples)

# %%
plt.figure()
plt.scatter(samples[:, 0], samples[:, 1])
plt.title("base distribution")
# Out:
# Text(0.5, 1.0, 'base distribution')

# %%
theta, a = getRandomVariables()
thetaSample = theta.sample()
aSample = a.sample()

# %%
normalizationFlow, transformedDistribution = performTransformation(baseDistribution,aSample,thetaSample)

# %%
transformedDistribution
# Out:
# <tfp.distributions._TransformedDistribution 'chain_of_tanh_of_F4_of_F3_of_scale_of_shiftMultivariateNormalDiag' batch_shape=[] event_shape=[2] dtype=float32>

# %%
colors =['tab:blue', 'tab:orange', 'tab:green','tab:purple']

# %%
nSamples = 1000

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 8))
for index,axis in enumerate(ax.flat):
  sa = a.sample()
  st = theta.sample()
  _,transformedDistribution = performTransformation(baseDistribution,sa,st)
  samples = transformedDistribution.sample(nSamples)
  axis.scatter(samples[:,0],samples[:,1],color = colors[index])
  axis.set_title(f"Distribution {index}"  + r'$ \rightarrow \alpha$ = ' + "{:.2f}".format(sa) + r' | $\theta$ = ' + "{:.2f}".format(st))

# %% [markdown]
# ## 2. Create the image dataset
# * You should now use your random normalising flow to generate an image dataset of contour plots from your random normalising flow network.
#   * Feel free to get creative and experiment with different architectures to produce different sets of images!
# * First, display a sample of 4 contour plot images from your normalising flow network using 4 independently sampled sets of parameters.
#   * You may find the following `get_densities` function useful: this calculates density values for a (batched) Distribution for use in a contour plot.
# * Your dataset should consist of at least 1000 images, stored in a numpy array of shape `(N, 36, 36, 3)`.  Each image in the dataset should correspond to a contour plot of a transformed distribution from a normalising flow with an independently sampled set of parameters $s, T, S, b$. It will take a few minutes to create the dataset.
# * As well as the `get_densities` function, the `get_image_array_from_density_values` function will help you to generate the dataset.
#   * This function creates a numpy array for an image of the contour plot for a given set of density values Z. Feel free to choose your own options for the contour plots.
# * Display a sample of 20 images from your generated dataset in a figure.

# %%
# Helper function to compute transformed distribution densities

X, Y = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-1, 1, 100))
inputs = np.transpose(np.stack((X, Y)), [1, 2, 0])

def get_densities(transformed_distribution):
    """
    This function takes a (batched) Distribution object as an argument, and returns a numpy 
    array Z of shape (batch_shape, 100, 100) of density values, that can be used to make a 
    contour plot with:
    plt.contourf(X, Y, Z[b, ...], cmap='hot', levels=100)
    where b is an index into the batch shape.
    """
    batch_shape = transformed_distribution.batch_shape
    Z = transformed_distribution.prob(np.expand_dims(inputs, 2))
    Z = np.transpose(Z, list(range(2, 2+len(batch_shape))) + [0, 1])
    return Z

# %%
# Helper function to convert contour plots to numpy arrays

import numpy as np
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

def get_image_array_from_density_values(Z):
    """
    This function takes a numpy array Z of density values of shape (100, 100)
    and returns an integer numpy array of shape (36, 36, 3) of pixel values for an image.
    """
    assert Z.shape == (100, 100)
    fig = Figure(figsize=(0.5, 0.5))
    canvas = FigureCanvas(fig)
    ax = fig.gca()
    ax.contourf(X, Y, Z, cmap='hot', levels=100)
    ax.axis('off')
    fig.tight_layout(pad=0)

    ax.margins(0)
    fig.canvas.draw()
    image_from_plot = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
    image_from_plot = image_from_plot.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    return image_from_plot

# %%
#transformedDist = performTransformation(baseDistribution,aSample,thetaSample)

# %%
def getManyRandomVariables(n):
  aDists = list()
  thetaDists = list()
  for _ in range(n):
    theta,a = getRandomVariables()
    thetaDists.append(theta)
    aDists.append(a)
  return thetaDists, aDists

# %%
def getImageSamples(n):
  #thetaDist,aList = getManyRandomVariables
  aList = tf.random.normal(shape=[n], mean=3)
  thetaDist = tf.random.uniform(shape=[n],minval = 0, maxval = pi) 
  transformedDists = [performTransformation(baseDistribution,a,theta)[1] for a,theta in zip(aList,thetaDist)]
  #Z = np.array([get_densities(td) for td in transformedDists])
  Z = np.array([td.prob(inputs) for td in transformedDists])
  images = np.array([get_image_array_from_density_values(z) for z in Z])
  return images

# %%
# 4 images dataset
images = 4
imageSample4 =  getImageSamples(images)
imageSample4.shape
# Out:
# (4, 36, 36, 3)

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 8))
for index,axis in enumerate(ax.flat):
  axis.imshow(imageSample4[index])

# %%
# 1000 images dataset
images = 1000
imageSample1000 =  getImageSamples(images)
imageSample1000.shape
# Out:
# (1000, 36, 36, 3)

# %%
indexes = np.linspace(0,999,1000).astype(np.int32)

# %%
img = imageSample1000[np.random.choice(indexes)]
img.shape
# Out:
# (36, 36, 3)

# %%
plt.imshow(img)

# %%
fig, axis = plt.subplots(4, 5, figsize=(8, 8))
for _,ax in enumerate(axis.flat):
  ax.imshow(imageSample1000[np.random.choice(indexes)])

# %%
axis
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faefb631d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faefb6315d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf0b93fd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf0b8ac2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf0b911890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf9007de50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf9013e250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf9d67bad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf200a5590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf9017a050>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf90151a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf9009b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf0ab9ed50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf0ac02490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf9016f910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf90160190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf0ac7f790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf900fad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf90137c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf9012c990>]],
#       dtype=object)

# %% [markdown]
# ## 3. Make `tf.data.Dataset` objects
# * You should now split your dataset to create `tf.data.Dataset` objects for training and validation data.
# * Using the `map` method, normalise the pixel values so that they lie between 0 and 1.
# * These Datasets will be used to train a variational autoencoder (VAE). Use the `map` method to return a tuple of input and output Tensors where the image is duplicated as both input and output.
# * Randomly shuffle the training Dataset.
# * Batch both datasets with a batch size of 20, setting `drop_remainder=True`.
# * Print the `element_spec` property for one of the Dataset objects.

# %%
dataset = imageSample1000.astype(np.float32)

# %%
length = dataset.shape[0]
length
# Out:
# 1000

# %%
from sklearn.model_selection import train_test_split

# %%
trainingImages, validationImages = train_test_split(dataset, test_size=0.2)

# %%
print(f"training shape: {trainingImages.shape}")
print(f"validation shape: {validationImages.shape}")
# Out:
# training shape: (800, 36, 36, 3)
# validation shape: (200, 36, 36, 3)

# %%
trainDataset = tf.data.Dataset.from_tensor_slices(trainingImages) 
valDataset = tf.data.Dataset.from_tensor_slices(validationImages)

# %%
batchSize = 20
trainFuffer = int(length*0.8)
valBuffer = int(length*0.2)

# %%
trainDataset = trainDataset.map(lambda x : (x/255.0,x/255.0))
trainDataset = trainDataset.shuffle(trainFuffer)
trainDataset = trainDataset.batch(batchSize,drop_remainder=True)

# %%
valDataset = valDataset.map(lambda x : (x/255.0,x/255.0))
valDataset = valDataset.shuffle(valBuffer)
valDataset = valDataset.batch(batchSize,drop_remainder=True)

# %% [markdown]
# ## 4. Build the encoder and decoder networks
# * You should now create the encoder and decoder for the variational autoencoder algorithm.
# * You should design these networks yourself, subject to the following constraints:
#    * The encoder and decoder networks should be built using the `Sequential` class.
#    * The encoder and decoder networks should use probabilistic layers where necessary to represent distributions.
#    * The prior distribution should be a zero-mean, isotropic Gaussian (identity covariance matrix).
#    * The encoder network should add the KL divergence loss to the model.
# * Print the model summary for the encoder and decoder networks.

# %%
from tensorflow.keras.layers import Conv2D, Dense,Flatten,BatchNormalization, Reshape
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
inputShape = dataset[0].shape
inputShape
# Out:
# (36, 36, 3)

# %%
dims = 2
prior = tfd.MultivariateNormalDiag(
    loc = tf.zeros(dims),
    scale_diag=tf.ones(dims)
)

# %%
def getEncoder(prior,inputShape = inputShape,dims = 2):
  encoder = Sequential(
      [
       Conv2D(256,activation="relu",padding='same',kernel_size=(3,3),strides = 2,input_shape = inputShape),
       BatchNormalization(),
       Conv2D(128,activation="relu",padding='same',kernel_size=(3,3),strides = 2),
       BatchNormalization(),
       Conv2D(64,activation="relu",padding='same',kernel_size=(3,3),strides = 2),
       BatchNormalization(),
       Flatten(),
       Dense(tfpl.MultivariateNormalTriL.params_size(dims)),
       tfpl.MultivariateNormalTriL(
           dims,
           activity_regularizer=tfpl.KLDivergenceRegularizer(prior)
       )
      ]
  )
  return encoder

# %%
encoder = getEncoder(prior)
encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 18, 18, 256)       7168
#
#  batch_normalization (BatchN  (None, 18, 18, 256)      1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 128)         295040
#
#  batch_normalization_1 (Batc  (None, 9, 9, 128)        512
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 64)          73792
#
#  batch_normalization_2 (Batc  (None, 5, 5, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 5)                 8005
#
#  multivariate_normal_tri_l (  ((None, 2),              0
#  MultivariateNormalTriL)      (None, 2))
#
# =================================================================
# Total params: 385,797
# Trainable params: 384,901
# Non-trainable params: 896
# _________________________________________________________________

# %%
def getDecoder(dims = 2,outputShape = inputShape):
  decoder = Sequential(
      [
       Dense(256, activation='relu', input_shape=(dims,)),
       Dense(4096, activation='relu'),
       Reshape((4,4,256)),
       Conv2D(32, (3, 3), padding='same'),
       BatchNormalization(),
       Conv2D(64, (3, 3), padding='same'),
       BatchNormalization(),
       Conv2D(256, (3, 3), padding='same'),
       Flatten(),
       Dense(tfpl.IndependentBernoulli.params_size(outputShape)),
       tfpl.IndependentBernoulli(outputShape)
      ]
  )
  return decoder

# %%
decoder = getDecoder()
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 256)               768
#
#  dense_2 (Dense)             (None, 4096)              1052672
#
#  reshape (Reshape)           (None, 4, 4, 256)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 32)          73760
#
#  batch_normalization_3 (Batc  (None, 4, 4, 32)         128
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          18496
#
#  batch_normalization_4 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 256)         147712
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 3888)              15929136
#
#  independent_bernoulli (Inde  ((None, 36, 36, 3),      0
#  pendentBernoulli)            (None, 36, 36, 3))
#
# =================================================================
# Total params: 17,222,928
# Trainable params: 17,222,736
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# ## 5. Train the variational autoencoder
# * You should now train the variational autoencoder. Build the VAE using the `Model` class and the encoder and decoder models. Print the model summary.
# * Compile the VAE with the negative log likelihood loss and train with the `fit` method, using the training and validation Datasets.
# * Plot the learning curves for loss vs epoch for both training and validation sets.

# %%
vae = Model(inputs=encoder.inputs, outputs=decoder(encoder.outputs))
vae.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 36, 36, 3)]       0
#
#  conv2d (Conv2D)             (None, 18, 18, 256)       7168
#
#  batch_normalization (BatchN  (None, 18, 18, 256)      1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 128)         295040
#
#  batch_normalization_1 (Batc  (None, 9, 9, 128)        512
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 64)          73792
#
#  batch_normalization_2 (Batc  (None, 5, 5, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 5)                 8005
#
#  multivariate_normal_tri_l (  ((None, 2),              0
#  MultivariateNormalTriL)      (None, 2))
#
#  sequential_1 (Sequential)   (None, 36, 36, 3)         17222928
#
# =================================================================
# Total params: 17,608,725
# Trainable params: 17,607,637
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
def lossFunction(imageBatch, decoderDist):
    return -tf.reduce_mean(decoderDist.log_prob(imageBatch))

# %%
optimizer = tf.keras.optimizers.Adam(1e-3)
vae.compile(
    optimizer=optimizer, 
    loss=lossFunction,
    )
stop = EarlyStopping(mode="min",patience = 10,min_delta = 5e-6,monitor ="val_loss")

# %%
history = vae.fit(trainDataset, validation_data=valDataset, epochs=500,callbacks=[stop])
# Out:
# Epoch 1/500
# 40/40 [==============================] - 13s 25ms/step - loss: 746.8304 - val_loss: 1502.2390
# Epoch 2/500
# 40/40 [==============================] - 0s 12ms/step - loss: 529.8541 - val_loss: 1031.6403
# Epoch 3/500
# 40/40 [==============================] - 0s 11ms/step - loss: 511.3499 - val_loss: 793.6800
# Epoch 4/500
# 40/40 [==============================] - 0s 12ms/step - loss: 495.7962 - val_loss: 740.1223
# Epoch 5/500
# 40/40 [==============================] - 0s 11ms/step - loss: 492.7629 - val_loss: 684.1559
# Epoch 6/500
# 40/40 [==============================] - 0s 11ms/step - loss: 488.6840 - val_loss: 660.8427
# Epoch 7/500
# 40/40 [==============================] - 0s 11ms/step - loss: 493.0014 - val_loss: 618.8768
# Epoch 8/500
# 40/40 [==============================] - 0s 11ms/step - loss: 479.2037 - val_loss: 661.0586
# Epoch 9/500
# 40/40 [==============================] - 0s 11ms/step - loss: 477.5218 - val_loss: 580.8423
# Epoch 10/500
# 40/40 [==============================] - 0s 12ms/step - loss: 479.4209 - val_loss: 574.8098
# Epoch 11/500
# 40/40 [==============================] - 0s 12ms/step - loss: 485.2392 - val_loss: 531.4725
# Epoch 12/500
# 40/40 [==============================] - 0s 12ms/step - loss: 478.1320 - val_loss: 531.4910
# Epoch 13/500
# 40/40 [==============================] - 0s 12ms/step - loss: 476.0555 - val_loss: 511.9532
# Epoch 14/500
# 40/40 [==============================] - 0s 11ms/step - loss: 470.2264 - val_loss: 505.3398
# Epoch 15/500
# 40/40 [==============================] - 0s 12ms/step - loss: 470.4786 - val_loss: 527.6680
# Epoch 16/500
# 40/40 [==============================] - 0s 11ms/step - loss: 477.7544 - val_loss: 484.5273
# Epoch 17/500
# 40/40 [==============================] - 0s 12ms/step - loss: 475.5181 - val_loss: 527.5131
# Epoch 18/500
# 40/40 [==============================] - 1s 12ms/step - loss: 476.3645 - val_loss: 484.0350
# Epoch 19/500
# 40/40 [==============================] - 0s 12ms/step - loss: 469.2865 - val_loss: 473.0735
# Epoch 20/500
# 40/40 [==============================] - 0s 12ms/step - loss: 464.9704 - val_loss: 468.8138
# Epoch 21/500
# 40/40 [==============================] - 0s 11ms/step - loss: 458.2340 - val_loss: 475.2024
# Epoch 22/500
# 40/40 [==============================] - 0s 12ms/step - loss: 470.1146 - val_loss: 480.5610
# Epoch 23/500
# 40/40 [==============================] - 0s 11ms/step - loss: 460.7282 - val_loss: 475.4793
# Epoch 24/500
# 40/40 [==============================] - 0s 12ms/step - loss: 458.2458 - val_loss: 468.1919
# Epoch 25/500
# 40/40 [==============================] - 1s 18ms/step - loss: 459.9240 - val_loss: 464.2567
# Epoch 26/500
# 40/40 [==============================] - 1s 14ms/step - loss: 457.7958 - val_loss: 472.1205
# Epoch 27/500
# 40/40 [==============================] - 1s 20ms/step - loss: 456.4223 - val_loss: 460.8223
# Epoch 28/500
# 40/40 [==============================] - 0s 12ms/step - loss: 453.3361 - val_loss: 460.5872
# Epoch 29/500
# 40/40 [==============================] - 1s 20ms/step - loss: 452.5166 - val_loss: 476.9475
# Epoch 30/500
# 40/40 [==============================] - 1s 12ms/step - loss: 455.4856 - val_loss: 463.3256
# Epoch 31/500
# 40/40 [==============================] - 0s 12ms/step - loss: 447.1752 - val_loss: 459.1236
# Epoch 32/500
# 40/40 [==============================] - 0s 12ms/step - loss: 448.4398 - val_loss: 456.6042
# Epoch 33/500
# 40/40 [==============================] - 0s 12ms/step - loss: 446.5953 - val_loss: 450.7635
# Epoch 34/500
# 40/40 [==============================] - 0s 12ms/step - loss: 445.7470 - val_loss: 461.1769
# Epoch 35/500
# 40/40 [==============================] - 0s 12ms/step - loss: 461.8335 - val_loss: 463.8170
# Epoch 36/500
# 40/40 [==============================] - 0s 12ms/step - loss: 446.4169 - val_loss: 463.3205
# Epoch 37/500
# 40/40 [==============================] - 0s 12ms/step - loss: 445.2063 - val_loss: 453.3475
# Epoch 38/500
# 40/40 [==============================] - 0s 12ms/step - loss: 457.1968 - val_loss: 465.2461
# Epoch 39/500
# 40/40 [==============================] - 0s 12ms/step - loss: 450.9099 - val_loss: 457.9217
# Epoch 40/500
# 40/40 [==============================] - 0s 11ms/step - loss: 446.1748 - val_loss: 456.8586
# Epoch 41/500
# 40/40 [==============================] - 0s 12ms/step - loss: 440.5233 - val_loss: 445.1537
# Epoch 42/500
# 40/40 [==============================] - 0s 11ms/step - loss: 438.1495 - val_loss: 463.9418
# Epoch 43/500
# 40/40 [==============================] - 0s 11ms/step - loss: 444.4492 - val_loss: 448.7924
# Epoch 44/500
# 40/40 [==============================] - 0s 12ms/step - loss: 440.2143 - val_loss: 448.8175
# Epoch 45/500
# 40/40 [==============================] - 0s 12ms/step - loss: 444.5889 - val_loss: 456.2044
# Epoch 46/500
# 40/40 [==============================] - 0s 12ms/step - loss: 447.5763 - val_loss: 456.3991
# Epoch 47/500
# 40/40 [==============================] - 0s 12ms/step - loss: 437.9925 - val_loss: 446.1034
# Epoch 48/500
# 40/40 [==============================] - 1s 12ms/step - loss: 435.7613 - val_loss: 447.9998
# Epoch 49/500
# 40/40 [==============================] - 0s 12ms/step - loss: 436.5731 - val_loss: 446.8344
# Epoch 50/500
# 40/40 [==============================] - 0s 12ms/step - loss: 442.8394 - val_loss: 450.9817
# Epoch 51/500
# 40/40 [==============================] - 0s 12ms/step - loss: 456.1241 - val_loss: 497.5132

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.figure()
plt.plot(history.history["loss"],label = "training")
plt.plot(history.history["val_loss"],label = "validation")
plt.xlabel('epoch')
plt.ylabel('ELBO')
plt.legend()

# %% [markdown]
# ## 6. Use the encoder and decoder networks
# * You can now put your encoder and decoder networks into practice!
# * Randomly sample 1000 images from the dataset, and pass them through the encoder. Display the embeddings in a scatter plot (project to 2 dimensions if the latent space has dimension higher than two).
# * Randomly sample 4 images from the dataset and for each image, display the original and reconstructed image from the VAE in a figure.
#   * Use the mean of the output distribution to display the images.
# * Randomly sample 6 latent variable realisations from the prior distribution, and display the images in a figure.
#   * Again use the mean of the output distribution to display the images.

# %%
encodedImages = encoder(imageSample1000)

# %%
encodedSampleImg = encodedImages.sample()
encodedSampleImg.shape
# Out:
# TensorShape([1000, 2])

# %%
plt.figure()
plt.scatter(encodedSampleImg[:,0],encodedSampleImg[:,1])
plt.title("Sample Encoder Outout")
# Out:
# Text(0.5, 1.0, 'Sample Encoder Outout')

# %%
def reconstruct(encoder,decoder,batches):
  return decoder(encoder(batches).mean()).mean()

# %%
sampleNumber = 4
indexes = np.random.choice(length,sampleNumber)
sampleImages = imageSample1000[indexes]

# %%
sampleImages[0].shape
# Out:
# (36, 36, 3)

# %%
plt.imshow(sampleImages[0])

# %%
# encode and reconstruct the sample images
reconstructed = reconstruct(encoder,decoder,sampleImages).numpy()

# %%
sampleImages.shape
# Out:
# (4, 36, 36, 3)

# %%
reconstructed.shape
# Out:
# (4, 36, 36, 3)

# %%
output = np.concatenate((sampleImages,reconstructed))

# %%
output.shape
# Out:
# (8, 36, 36, 3)

# %%
output[0,:].shape
# Out:
# (36, 36, 3)

# %%
fig, axis = plt.subplots(2, 4, figsize=(8, 8))
for index,ax in enumerate(axis.flat):
  ax.imshow(output[index])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Make a video of latent space interpolation (not assessed)
# * Just for fun, you can run the code below to create a video of your decoder's generations, depending on the latent space.

# %%
# Function to create animation

import matplotlib.animation as anim
from IPython.display import HTML


def get_animation(latent_size, decoder, interpolation_length=500):
    assert latent_size >= 2, "Latent space must be at least 2-dimensional for plotting"
    fig = plt.figure(figsize=(9, 4))  
    ax1 = fig.add_subplot(1,2,1)
    ax1.set_xlim([-3, 3])
    ax1.set_ylim([-3, 3])
    ax1.set_title("Latent space")
    ax1.axes.get_xaxis().set_visible(False)
    ax1.axes.get_yaxis().set_visible(False)
    ax2 = fig.add_subplot(1,2,2)
    ax2.set_title("Data space")
    ax2.axes.get_xaxis().set_visible(False)
    ax2.axes.get_yaxis().set_visible(False)

    # initializing a line variable 
    line, = ax1.plot([], [], marker='o')
    img2 = ax2.imshow(np.zeros((36, 36, 3)))

    freqs = np.random.uniform(low=0.1, high=0.2, size=(latent_size,))
    phases = np.random.randn(latent_size)
    input_points = np.arange(interpolation_length)
    latent_coords = []
    for i in range(latent_size):
        latent_coords.append(2 * np.sin((freqs[i]*input_points + phases[i])).astype(np.float32))

    def animate(i): 
        z = tf.constant([coord[i] for coord in latent_coords])
        img_out = np.squeeze(decoder(z[np.newaxis, ...]).mean().numpy())
        line.set_data(z.numpy()[0], z.numpy()[1])
        img2.set_data(np.clip(img_out, 0, 1))
        return (line, img2)

    return anim.FuncAnimation(fig, animate, frames=interpolation_length, 
                              repeat=False, blit=True, interval=150)

# %%
# Create the animation
latent_size = 2
a = get_animation(latent_size, decoder, interpolation_length=200)
HTML(a.to_html5_video())
# Out:
# <video width="648" height="288" controls autoplay>
#   <source type="video/mp4" src="...
